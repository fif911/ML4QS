# %%
import pandas as pd

dataset = pd.read_csv("../phyphox-outputs/chapter2_result_250_labeled_aligned.csv", skipinitialspace=True)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29948 entries, 0 to 29947
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  29948 non-null  object
#  1   acc_x                       29948 non-null  float64
#  2   acc_y                       29948 non-null  float64
#  3   acc_z                       29948 non-null  float64
#  4   label                       29948 non-null  object
#  5   gyr_x                       29945 non-null  float64
#  6   gyr_y                       29945 non-null  float64
#  7   gyr_z                       29945 non-null  float64
#  8   lin_acc_x                   29944 non-null  float64
#  9   lin_acc_y                   29944 non-null  float64
#  10  lin_acc_z                   29944 non-null  float64
#  11  loc_Latitude (°)            6298 non-null   float64
#  12  loc_Longitude (°)           6298 non-null   float64
#  13  loc_height                  6298 non-null   float64
#  14  loc_speed                   6298 non-null   float64
#  15  loc_Direction (°)           6298 non-null   float64
#  16  loc_horizontal_accuracy     6298 non-null   float64
#  17  loc_vertical_accuracy       6298 non-null   float64
#  18  mang_Magnetic field x (µT)  29941 non-null  float64
#  19  mang_Magnetic field y (µT)  29941 non-null  float64
#  20  mang_Magnetic field z (µT)  29941 non-null  float64
# dtypes: float64(19), object(2)
# memory usage: 4.8+ MB

# %%
from Python3Code.util.VisualizeDataset import VisualizeDataset
from Python3Code.Chapter3.OutlierDetection import DistributionBasedOutlierDetection, DistanceBasedOutlierDetection

# Create the outlier classes.
OutlierDistr = DistributionBasedOutlierDetection()
OutlierDist = DistanceBasedOutlierDetection()
DataViz = VisualizeDataset("main")

# %%
outlier_columns = ["loc_speed"]
for col in outlier_columns:

    print(f"Applying Chauvenet outlier criteria for column {col}")

    # And try out all different approaches. Note that we have done some optimization
    # of the parameter values for each of the approaches by visual inspection.
    dataset = OutlierDistr.chauvenet(dataset, col, 2)
    DataViz.plot_binary_outliers(
        dataset, col, col + '_outlier')
# Out:
# Applying Chauvenet outlier criteria for column loc_speed
# Figure saved to figures/main/figure_4.png
# Figure saved to figures/main/figure_4.pdf

# %%
outlier_columns = ["loc_speed"]

for col in outlier_columns:

    print(f"Applying mixture model for column {col}")
    dataset = OutlierDistr.mixture_model(dataset, col, 3)
    DataViz.plot_dataset(dataset, [
                         col, col + '_mixture'], ['exact', 'exact'], ['line', 'points'])
# Out:
# Applying mixture model for column loc_speed
# Applying mixture models
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 7
#       5 print(f"Applying mixture model for column {col}")
#       6 dataset = OutlierDistr.mixture_model(dataset, col, 3)
# ----> 7 DataViz.plot_dataset(dataset, [
#       8                      col, col + '_mixture'], ['exact', 'exact'], ['line', 'points'])
#
# File ~/PycharmProjects/ML4QS/Python3Code/util/VisualizeDataset.py:87, in VisualizeDataset.plot_dataset(self, data_table, columns, match, display)
#      85 # Display point, or as a line
#      86 if display[i] == 'points':
# ---> 87     xar[i].plot(data_table.index[mask], data_table[relevant_cols[j]][mask],
#      88                 self.point_displays[j%len(self.point_displays)])
#      89 else:
#      90     xar[i].plot(data_table.index[mask], data_table[relevant_cols[j]][mask],
#      91                 self.line_displays[j%len(self.line_displays)])
#
# File ~/anaconda3/envs/myenv/lib/python3.8/site-packages/pandas/core/indexes/range.py:979, in RangeIndex.__getitem__(self, key)
#     972     raise IndexError(
#     973         "only integers, slices (`:`), "
#     974         "ellipsis (`...`), numpy.newaxis (`None`) "
#     975         "and integer or boolean "
#     976         "arrays are valid indices"
#     977     )
#     978 # fall back to Int64Index
# --> 979 return super().__getitem__(key)
#
# File ~/anaconda3/envs/myenv/lib/python3.8/site-packages/pandas/core/indexes/base.py:5339, in Index.__getitem__(self, key)
#    5336     else:
#    5337         key = np.asarray(key, dtype=bool)
# -> 5339 result = getitem(key)
#    5340 # Because we ruled out integer above, we always get an arraylike here
#    5341 if result.ndim > 1:
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
outlier_columns = ["acc_x","acc_y","acc_z", "loc_speed"]
for col in outlier_columns:
    try:
        dataset = OutlierDist.local_outlier_factor(
            dataset, [col], 'euclidean', 5)
        DataViz.plot_dataset(dataset, [col, 'lof'], [
                             'exact', 'exact'], ['line', 'points'])
    except MemoryError as e:
        print('Not enough memory available for lof...')
        print('Skipping.')
# Out:
# Calculating local outlier factor.
# Completed 0 steps for LOF out of 29948.
# Completed 100 steps for LOF out of 29948.
# Completed 200 steps for LOF out of 29948.
# Completed 300 steps for LOF out of 29948.
# Completed 400 steps for LOF out of 29948.
# Completed 500 steps for LOF out of 29948.
# Completed 600 steps for LOF out of 29948.
# Completed 700 steps for LOF out of 29948.
# Completed 800 steps for LOF out of 29948.
# Completed 900 steps for LOF out of 29948.
# Completed 1000 steps for LOF out of 29948.
# Completed 1100 steps for LOF out of 29948.
# Completed 1200 steps for LOF out of 29948.
# Completed 1300 steps for LOF out of 29948.
# Completed 1400 steps for LOF out of 29948.
# Completed 1500 steps for LOF out of 29948.
# Completed 1600 steps for LOF out of 29948.
# Completed 1700 steps for LOF out of 29948.
# Completed 1800 steps for LOF out of 29948.
# Completed 1900 steps for LOF out of 29948.
# Completed 2000 steps for LOF out of 29948.
# Completed 2100 steps for LOF out of 29948.
# Completed 2200 steps for LOF out of 29948.
# Completed 2300 steps for LOF out of 29948.
# Completed 2400 steps for LOF out of 29948.
# Completed 2500 steps for LOF out of 29948.
# Completed 2600 steps for LOF out of 29948.
# Completed 2700 steps for LOF out of 29948.
# Completed 2800 steps for LOF out of 29948.
# Completed 2900 steps for LOF out of 29948.
# Completed 3000 steps for LOF out of 29948.
# Completed 3100 steps for LOF out of 29948.
# Completed 3200 steps for LOF out of 29948.
# Completed 3300 steps for LOF out of 29948.
# Completed 3400 steps for LOF out of 29948.
# Completed 3500 steps for LOF out of 29948.
# Completed 3600 steps for LOF out of 29948.
# Completed 3700 steps for LOF out of 29948.
# Completed 3800 steps for LOF out of 29948.
# Completed 3900 steps for LOF out of 29948.
# Completed 4000 steps for LOF out of 29948.
# Completed 4100 steps for LOF out of 29948.
# Completed 4200 steps for LOF out of 29948.
# Completed 4300 steps for LOF out of 29948.
# Completed 4400 steps for LOF out of 29948.
# Completed 4500 steps for LOF out of 29948.
# Completed 4600 steps for LOF out of 29948.
# Completed 4700 steps for LOF out of 29948.
# Completed 4800 steps for LOF out of 29948.
# Completed 4900 steps for LOF out of 29948.
# Completed 5000 steps for LOF out of 29948.
# Completed 5100 steps for LOF out of 29948.
# Completed 5200 steps for LOF out of 29948.
# Completed 5300 steps for LOF out of 29948.
# Completed 5400 steps for LOF out of 29948.
# Completed 5500 steps for LOF out of 29948.
# Completed 5600 steps for LOF out of 29948.
# Completed 5700 steps for LOF out of 29948.
# Completed 5800 steps for LOF out of 29948.
# Completed 5900 steps for LOF out of 29948.
# Completed 6000 steps for LOF out of 29948.
# Completed 6100 steps for LOF out of 29948.
# Completed 6200 steps for LOF out of 29948.
# Completed 6300 steps for LOF out of 29948.
# Completed 6400 steps for LOF out of 29948.
# Completed 6500 steps for LOF out of 29948.
# Completed 6600 steps for LOF out of 29948.
# Completed 6700 steps for LOF out of 29948.
# Completed 6800 steps for LOF out of 29948.
# Completed 6900 steps for LOF out of 29948.
# Completed 7000 steps for LOF out of 29948.
# Completed 7100 steps for LOF out of 29948.
# Completed 7200 steps for LOF out of 29948.
# Completed 7300 steps for LOF out of 29948.
# Completed 7400 steps for LOF out of 29948.
# Completed 7500 steps for LOF out of 29948.
# Completed 7600 steps for LOF out of 29948.
# Completed 7700 steps for LOF out of 29948.
# Completed 7800 steps for LOF out of 29948.
# Completed 7900 steps for LOF out of 29948.
# Completed 8000 steps for LOF out of 29948.
# Completed 8100 steps for LOF out of 29948.
# Completed 8200 steps for LOF out of 29948.
# Completed 8300 steps for LOF out of 29948.
# Completed 8400 steps for LOF out of 29948.
# Completed 8500 steps for LOF out of 29948.
# Completed 8600 steps for LOF out of 29948.
# Completed 8700 steps for LOF out of 29948.
# Completed 8800 steps for LOF out of 29948.
# Completed 8900 steps for LOF out of 29948.
# Completed 9000 steps for LOF out of 29948.
# Completed 9100 steps for LOF out of 29948.
# Completed 9200 steps for LOF out of 29948.
# Completed 9300 steps for LOF out of 29948.
# Completed 9400 steps for LOF out of 29948.
# Completed 9500 steps for LOF out of 29948.
# Completed 9600 steps for LOF out of 29948.
# Completed 9700 steps for LOF out of 29948.
# Completed 9800 steps for LOF out of 29948.
# Completed 9900 steps for LOF out of 29948.
# Completed 10000 steps for LOF out of 29948.
# Completed 10100 steps for LOF out of 29948.
# Completed 10200 steps for LOF out of 29948.
# Completed 10300 steps for LOF out of 29948.
# Completed 10400 steps for LOF out of 29948.
# Completed 10500 steps for LOF out of 29948.
# Completed 10600 steps for LOF out of 29948.
# Completed 10700 steps for LOF out of 29948.
# Completed 10800 steps for LOF out of 29948.
# Completed 10900 steps for LOF out of 29948.
# Completed 11000 steps for LOF out of 29948.
# Completed 11100 steps for LOF out of 29948.
# Completed 11200 steps for LOF out of 29948.
# Completed 11300 steps for LOF out of 29948.
# Completed 11400 steps for LOF out of 29948.
# Completed 11500 steps for LOF out of 29948.
# Completed 11600 steps for LOF out of 29948.
# Completed 11700 steps for LOF out of 29948.
# Completed 11800 steps for LOF out of 29948.
# Completed 11900 steps for LOF out of 29948.
# Completed 12000 steps for LOF out of 29948.
# Completed 12100 steps for LOF out of 29948.
# Completed 12200 steps for LOF out of 29948.
# Completed 12300 steps for LOF out of 29948.
# Completed 12400 steps for LOF out of 29948.
# Completed 12500 steps for LOF out of 29948.
# Completed 12600 steps for LOF out of 29948.
# Completed 12700 steps for LOF out of 29948.
# Completed 12800 steps for LOF out of 29948.
# Completed 12900 steps for LOF out of 29948.
# Completed 13000 steps for LOF out of 29948.
# Completed 13100 steps for LOF out of 29948.
# Completed 13200 steps for LOF out of 29948.
# Completed 13300 steps for LOF out of 29948.
# Completed 13400 steps for LOF out of 29948.
# Completed 13500 steps for LOF out of 29948.
# Completed 13600 steps for LOF out of 29948.
# Completed 13700 steps for LOF out of 29948.
# Completed 13800 steps for LOF out of 29948.
# Completed 13900 steps for LOF out of 29948.
# Completed 14000 steps for LOF out of 29948.
# Completed 14100 steps for LOF out of 29948.
# Completed 14200 steps for LOF out of 29948.
# Completed 14300 steps for LOF out of 29948.
# Completed 14400 steps for LOF out of 29948.
# Completed 14500 steps for LOF out of 29948.
# Completed 14600 steps for LOF out of 29948.
# Completed 14700 steps for LOF out of 29948.
# Completed 14800 steps for LOF out of 29948.
# Completed 14900 steps for LOF out of 29948.
# Completed 15000 steps for LOF out of 29948.
# Completed 15100 steps for LOF out of 29948.
# Completed 15200 steps for LOF out of 29948.
# Completed 15300 steps for LOF out of 29948.
# Completed 15400 steps for LOF out of 29948.
# Completed 15500 steps for LOF out of 29948.
# Completed 15600 steps for LOF out of 29948.
# Completed 15700 steps for LOF out of 29948.
# Completed 15800 steps for LOF out of 29948.
# Completed 15900 steps for LOF out of 29948.
# Completed 16000 steps for LOF out of 29948.
# Completed 16100 steps for LOF out of 29948.
# Completed 16200 steps for LOF out of 29948.
# Completed 16300 steps for LOF out of 29948.
# Completed 16400 steps for LOF out of 29948.
# Completed 16500 steps for LOF out of 29948.
# Completed 16600 steps for LOF out of 29948.
# Completed 16700 steps for LOF out of 29948.
# Completed 16800 steps for LOF out of 29948.
# Completed 16900 steps for LOF out of 29948.
# Completed 17000 steps for LOF out of 29948.
# Completed 17100 steps for LOF out of 29948.
# Completed 17200 steps for LOF out of 29948.
# Completed 17300 steps for LOF out of 29948.
# Completed 17400 steps for LOF out of 29948.
# Completed 17500 steps for LOF out of 29948.
# Completed 17600 steps for LOF out of 29948.
# Completed 17700 steps for LOF out of 29948.
# Completed 17800 steps for LOF out of 29948.
# Completed 17900 steps for LOF out of 29948.
# Completed 18000 steps for LOF out of 29948.
# Completed 18100 steps for LOF out of 29948.
# Completed 18200 steps for LOF out of 29948.
# Completed 18300 steps for LOF out of 29948.
# Completed 18400 steps for LOF out of 29948.
# Completed 18500 steps for LOF out of 29948.
# Completed 18600 steps for LOF out of 29948.
# Completed 18700 steps for LOF out of 29948.
# Completed 18800 steps for LOF out of 29948.
# Completed 18900 steps for LOF out of 29948.
# Completed 19000 steps for LOF out of 29948.
# Completed 19100 steps for LOF out of 29948.
# Completed 19200 steps for LOF out of 29948.
# Completed 19300 steps for LOF out of 29948.
# Completed 19400 steps for LOF out of 29948.
# Completed 19500 steps for LOF out of 29948.
# Completed 19600 steps for LOF out of 29948.
# Completed 19700 steps for LOF out of 29948.
# Completed 19800 steps for LOF out of 29948.
# Completed 19900 steps for LOF out of 29948.
# Completed 20000 steps for LOF out of 29948.
# Completed 20100 steps for LOF out of 29948.
# Completed 20200 steps for LOF out of 29948.
# Completed 20300 steps for LOF out of 29948.
# Completed 20400 steps for LOF out of 29948.
# Completed 20500 steps for LOF out of 29948.
# Completed 20600 steps for LOF out of 29948.
# Completed 20700 steps for LOF out of 29948.
# Completed 20800 steps for LOF out of 29948.
# Completed 20900 steps for LOF out of 29948.
# Completed 21000 steps for LOF out of 29948.
# Completed 21100 steps for LOF out of 29948.
# Completed 21200 steps for LOF out of 29948.
# Completed 21300 steps for LOF out of 29948.
# Completed 21400 steps for LOF out of 29948.
# Completed 21500 steps for LOF out of 29948.
# Completed 21600 steps for LOF out of 29948.
# Completed 21700 steps for LOF out of 29948.
# Completed 21800 steps for LOF out of 29948.
# Completed 21900 steps for LOF out of 29948.
# Completed 22000 steps for LOF out of 29948.
# Completed 22100 steps for LOF out of 29948.
# Completed 22200 steps for LOF out of 29948.
# Completed 22300 steps for LOF out of 29948.
# Completed 22400 steps for LOF out of 29948.
# Completed 22500 steps for LOF out of 29948.
# Completed 22600 steps for LOF out of 29948.
# Completed 22700 steps for LOF out of 29948.
# Completed 22800 steps for LOF out of 29948.
# Completed 22900 steps for LOF out of 29948.
# Completed 23000 steps for LOF out of 29948.
# Completed 23100 steps for LOF out of 29948.
# Completed 23200 steps for LOF out of 29948.
# Completed 23300 steps for LOF out of 29948.
# Completed 23400 steps for LOF out of 29948.
# Completed 23500 steps for LOF out of 29948.
# Completed 23600 steps for LOF out of 29948.
# Completed 23700 steps for LOF out of 29948.
# Completed 23800 steps for LOF out of 29948.
# Completed 23900 steps for LOF out of 29948.
# Completed 24000 steps for LOF out of 29948.
# Completed 24100 steps for LOF out of 29948.
# Completed 24200 steps for LOF out of 29948.
# Completed 24300 steps for LOF out of 29948.
# Completed 24400 steps for LOF out of 29948.
# Completed 24500 steps for LOF out of 29948.
# Completed 24600 steps for LOF out of 29948.
# Completed 24700 steps for LOF out of 29948.
# Completed 24800 steps for LOF out of 29948.
# Completed 24900 steps for LOF out of 29948.
# Completed 25000 steps for LOF out of 29948.
# Completed 25100 steps for LOF out of 29948.
# Completed 25200 steps for LOF out of 29948.
# Completed 25300 steps for LOF out of 29948.
# Completed 25400 steps for LOF out of 29948.
# Completed 25500 steps for LOF out of 29948.
# Completed 25600 steps for LOF out of 29948.
# Completed 25700 steps for LOF out of 29948.
# Completed 25800 steps for LOF out of 29948.
# Completed 25900 steps for LOF out of 29948.
# Completed 26000 steps for LOF out of 29948.
# Completed 26100 steps for LOF out of 29948.
# Completed 26200 steps for LOF out of 29948.
# Completed 26300 steps for LOF out of 29948.
# Completed 26400 steps for LOF out of 29948.
# Completed 26500 steps for LOF out of 29948.
# Completed 26600 steps for LOF out of 29948.
# Completed 26700 steps for LOF out of 29948.
# Completed 26800 steps for LOF out of 29948.
# Completed 26900 steps for LOF out of 29948.
# Completed 27000 steps for LOF out of 29948.
# Completed 27100 steps for LOF out of 29948.
# Completed 27200 steps for LOF out of 29948.
# Completed 27300 steps for LOF out of 29948.
# Completed 27400 steps for LOF out of 29948.
# Completed 27500 steps for LOF out of 29948.
# Completed 27600 steps for LOF out of 29948.
# Completed 27700 steps for LOF out of 29948.
# Completed 27800 steps for LOF out of 29948.
# Completed 27900 steps for LOF out of 29948.
# Completed 28000 steps for LOF out of 29948.
# Completed 28100 steps for LOF out of 29948.
# Completed 28200 steps for LOF out of 29948.
# Completed 28300 steps for LOF out of 29948.
# Completed 28400 steps for LOF out of 29948.
# Completed 28500 steps for LOF out of 29948.
# Completed 28600 steps for LOF out of 29948.
# Completed 28700 steps for LOF out of 29948.
# Completed 28800 steps for LOF out of 29948.
# Completed 28900 steps for LOF out of 29948.
# Completed 29000 steps for LOF out of 29948.
# Completed 29100 steps for LOF out of 29948.
# Completed 29200 steps for LOF out of 29948.
# Completed 29300 steps for LOF out of 29948.
# Completed 29400 steps for LOF out of 29948.
# Completed 29500 steps for LOF out of 29948.
# Completed 29600 steps for LOF out of 29948.
# Completed 29700 steps for LOF out of 29948.
# Completed 29800 steps for LOF out of 29948.
# Completed 29900 steps for LOF out of 29948.
# Figure saved to figures/main/figure_1.png
# Figure saved to figures/main/figure_1.pdf
# Calculating local outlier factor.
# Completed 0 steps for LOF out of 29948.
# Completed 100 steps for LOF out of 29948.
# Completed 200 steps for LOF out of 29948.
# Completed 300 steps for LOF out of 29948.
# Completed 400 steps for LOF out of 29948.
# Completed 500 steps for LOF out of 29948.
# Completed 600 steps for LOF out of 29948.
# Completed 700 steps for LOF out of 29948.
# Completed 800 steps for LOF out of 29948.
# Completed 900 steps for LOF out of 29948.
# Completed 1000 steps for LOF out of 29948.
# Completed 1100 steps for LOF out of 29948.
# Completed 1200 steps for LOF out of 29948.
# Completed 1300 steps for LOF out of 29948.
# Completed 1400 steps for LOF out of 29948.
# Completed 1500 steps for LOF out of 29948.
# Completed 1600 steps for LOF out of 29948.
# Completed 1700 steps for LOF out of 29948.
# Completed 1800 steps for LOF out of 29948.
# Completed 1900 steps for LOF out of 29948.
# Completed 2000 steps for LOF out of 29948.
# Completed 2100 steps for LOF out of 29948.
# Completed 2200 steps for LOF out of 29948.
# Completed 2300 steps for LOF out of 29948.
# Completed 2400 steps for LOF out of 29948.
# Completed 2500 steps for LOF out of 29948.
# Completed 2600 steps for LOF out of 29948.
# Completed 2700 steps for LOF out of 29948.
# Completed 2800 steps for LOF out of 29948.
# Completed 2900 steps for LOF out of 29948.
# Completed 3000 steps for LOF out of 29948.
# Completed 3100 steps for LOF out of 29948.
# Completed 3200 steps for LOF out of 29948.
# Completed 3300 steps for LOF out of 29948.
# Completed 3400 steps for LOF out of 29948.
# Completed 3500 steps for LOF out of 29948.
# Completed 3600 steps for LOF out of 29948.
# Completed 3700 steps for LOF out of 29948.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 for col in outlier_columns:
#       3     try:
# ----> 4         dataset = OutlierDist.local_outlier_factor(
#       5             dataset, [col], 'euclidean', 5)
#       6         DataViz.plot_dataset(dataset, [col, 'lof'], [
#       7                              'exact', 'exact'], ['line', 'points'])
#       8     except MemoryError as e:
#
# File ~/PycharmProjects/ML4QS/Python3Code/Chapter3/OutlierDetection.py:139, in DistanceBasedOutlierDetection.local_outlier_factor(self, data_table, cols, d_function, k)
#     137 for i in range(0, len(new_data_table.index)):
#     138     if i % 100 == 0: print(f'Completed {i} steps for LOF out of {len(new_data_table.index)}.')
# --> 139     outlier_factor.append(self.local_outlier_factor_instance(i, k))
#     140 if data_table.get('lof') is None:
#     141     data_outlier_probs = pd.DataFrame(
#     142         outlier_factor, index=new_data_table.index, columns=['lof'])
#
# File ~/PycharmProjects/ML4QS/Python3Code/Chapter3/OutlierDetection.py:187, in DistanceBasedOutlierDetection.local_outlier_factor_instance(self, i, k)
#     185 k_distance_value, neighbors = self.k_distance(i, k)
#     186 # Computer the local reachability given the found k-distance and neighbors.
# --> 187 instance_lrd = self.local_reachability_density(i, k, k_distance_value, neighbors)
#     188 lrd_ratios_array = [0] * len(neighbors)
#     190 # Computer the k-distances and local reachability density of the neighbors
#
# File ~/PycharmProjects/ML4QS/Python3Code/Chapter3/OutlierDetection.py:165, in DistanceBasedOutlierDetection.local_reachability_density(self, instance, k, k_distance_i, neighbors_i)
#     163 # Compute the reachability distance between i and all neighbors.
#     164 for i, neighbor in enumerate(neighbors_i):
# --> 165     reachability_distances_array[i] = self.reachability_distance(k, instance, neighbor)
#     166 if (not any(reachability_distances_array)) or (sum(reachability_distances_array) == 0):
#     167     return float(self.HIGH_VALUE)
#
# File ~/PycharmProjects/ML4QS/Python3Code/Chapter3/OutlierDetection.py:152, in DistanceBasedOutlierDetection.reachability_distance(self, k, i1, i2)
#     150 def reachability_distance(self, k, i1, i2):
#     151     # Compute the k-distance of i2.
# --> 152     k_distance_value, neighbors = self.k_distance(i2, k)
#     153     # The value is the max of the k-distance of i2 and the real distance.
#     154     return max([k_distance_value, self.distances.iloc[i1, i2]])
#
# File ~/PycharmProjects/ML4QS/Python3Code/Chapter3/OutlierDetection.py:177, in DistanceBasedOutlierDetection.k_distance(self, i, k)
#     174 def k_distance(self, i, k):
#     175     # Simply look up the values in the distance table, select the min_pts^th lowest value and take the value pairs
#     176     # Take min_pts + 1 as we also have the instance itself in there.
# --> 177     neighbors = np.argpartition(np.array(self.distances.iloc[i,:]), k+1)[0:(k+1)].tolist()
#     178     if i in neighbors:
#     179         neighbors.remove(i)
#
# File <__array_function__ internals>:200, in argpartition(*args, **kwargs)
#
# File ~/anaconda3/envs/myenv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:871, in argpartition(a, kth, axis, kind, order)
#     792 @array_function_dispatch(_argpartition_dispatcher)
#     793 def argpartition(a, kth, axis=-1, kind='introselect', order=None):
#     794     """
#     795     Perform an indirect partition along the given axis using the
#     796     algorithm specified by the `kind` keyword. It returns an array of
#    (...)
#     869
#     870     """
# --> 871     return _wrapfunc(a, 'argpartition', kth, axis=axis, kind=kind, order=order)
#
# File ~/anaconda3/envs/myenv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:
